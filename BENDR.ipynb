# %%
# !python3 downstream.py linear --random-init --results-filename "results/linear_random_init.xlsx"
# !python3 downstream.py BENDR --random-init --results-filename "results/BENDR_random_init.xlsx"
# Out:
# Namespace(ds_config='configs/downstream.yml', freeze_encoder=False, mdl=False, metrics_config='configs/metrics.yml', model='linear', multi_gpu=False, num_workers=4, random_init=True, results_filename='results/linear_random_init.xlsx', subject_specific=False)
# Traceback (most recent call last):
#   File "downstream.py", line 39, in <module>
#     experiment = ExperimentConfig(args.ds_config)
#   File "/opt/conda/lib/python3.8/site-packages/dn3/configuratron/config.py", line 117, in __init__
#     self.datasets[name] = DatasetConfig(name, ds_entries[name], deep1010=self._make_deep1010,
#   File "/opt/conda/lib/python3.8/site-packages/dn3/configuratron/config.py", line 244, in __init__
#     raise DN3ConfigException("The toplevel {} for dataset {} does not exists".format(self.toplevel, self.name))
# dn3.utils.DN3ConfigException: The toplevel /<path/to>/physionet.org/files/eegmmidb for dataset Physionet MMIDB does not exists
# ...

# %% [raw]
# downlstream.yaml
#
# Configuratron:
#   use_only:
#     - mmidb
#     - bci_iv_2a
# #     - ern
#     - erpbci
#     - sleep-edf
#   preload: True
#   sfreq: 256
#   deep1010:
#     return_mask: False
#
# encoder_weights: <saved encoder weights>
# context_weights: <saved transformer weights>
#
# datasets: !include configs/downstream_datasets.yml
#
# ====
# mmidb:
#   name: "Physionet MMIDB"
#   toplevel: /<path/to>/physionet.org/files/eegmmidb/
#   tmin: 0
#   tlen: 6
#   data_max: 0.001
#   data_min: -0.001
#   events:
#     - T1
#     - T2
#   exclude_sessions:
#     - "*R0[!48].edf"  # equivalently "*R0[1235679].edf"
#     - "*R1[!2].edf"   # equivalently "*R1[134].edf"
#   exclude_people:
#     - S088
#     - S090
#     - S092
#     - S100
#   train_params:
#     epochs: 7
#     batch_size: 4 # I find this dataset likes small batch sizes
#   lr: 0.00001
#   folds: 5
#
#
# bci_iv_2a:
#   name: "BCI Competition IV 2a"
#   toplevel: <path>
#   tmin: -2
#   tlen: 6
#   data_max: 100
#   data_min: -100
#   extensions:
#     - .raw.fif
#   picks:
#     - eeg
#   train_params:
#     epochs: 15
#     batch_size: 60 # This dataset likes batches of ~60 (community is overfitting this)
#   lr: 0.00005
#
# ern:
#   name: "Kaggle ERN Competition"
#   toplevel: <path>
#   tmin: -0.7
#   tlen: 2
#   data_max: 3500
#   data_min: -4010
#   extensions:
#     - .raw.fif
#   picks:
#     - eeg
#   rename_channels:
#     PO8: P08
#   exclude_channels:
#     - FeedBackEvent
#   test_subjects:
#     - S01
#     - S03
#     - S04
#     - S05
#     - S08
#     - S09
#     - S10
#     - S15
#     - S19
#     - S25
#   train_params:
#     epochs: 15
#     batch_size: 32
#     balance_method: undersample
#   lr: 0.00001
#   folds: 4
#
# sleep-edf:
#   name: "Sleep EDFx Cassette"
#   filename_format: "SC4{subject:2}{session:1}"
#   annotation_format: "SC4{subject:2}{session:1}*Hypnogram*"
#   toplevel: /<path/to>/physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/
#   tmin: 0
#   tlen: 30
#   data_max: 4460.6
#   data_min: -4465.7
#   extensions:
#     - .edf
#   chunk_duration: 30
#   events:
#     'Sleep stage W': 0
#     'Sleep stage 1': 1
#     'Sleep stage 2': 2
#     'Sleep stage 3': 3
#     'Sleep stage 4': 3
#     'Sleep stage R': 4
#   rename_channels:
#     FPZ: 'EEG Fpz-Cz'
#     PZ: 'EEG Pz-Oz'
#     HEOGL: "EOG horizontal"
#   picks:
#     - eeg
#   exclude_channels:
#     - "Resp oro-nasal"
#     - 'EMG submental'
#     - 'Temp rectal' # Comfiest sleep ever
#     - 'Event marker'
#   train_params:
#     epochs: 40
#     batch_size: 80
#     balance_method: undersample
#     validation_interval: 1000
#   lr: 0.00005
#   folds: 10
#
#
# erpbci:
#   data_max: 0.00631
#   data_min: -0.00283
#   toplevel: /<path/to>/erpbci/1.0.0
#   tmin: -0.1
#   tlen: 0.7
#   # We low-passed offline using this parameter just so it didn't happen over and over.
#   # Uncommenting this and part of LoaderERPBCI in dn3_ext.py should reproduce the same results (it says where)
# #  lpf: 120
#   extensions:
#   # Swap the following for using default dataset
# #    - .edf
#     - .fif
#   picks:
#     - eeg
#   exclude_people:
#     - s08
#     - s12
#     - s10
#     # This stronge person shouldn't affect anyone else, if it does just comment them out
#     - BENDR
#   train_params:
#     epochs: 20
#     batch_size: 64
#     balance_method: undersample
#   lr: 0.00001

# %% [markdown]
# # BCI Competition IV: Download area
# ## Data Set 1
# ### from Berlin (description)
# - 100Hz data: [ Matlab files zipped (209 MB) ] [ ASCII files zipped (206 MB) ]
# (signals have been low-pass filtered at 49Hz before subsampling)
#
# https://www.bbci.de/competition/download/competition_iv/BCICIV_1_mat.zip
# https://www.bbci.de/competition/download/competition_iv/BCICIV_1_asc.zip
#
# - 1000Hz data: [ Matlab files zipped: calib (1.1 GB) | eval (1.2 GB) ] [ ASCII files zipped: calib (1.3 GB) | eval (1.4 GB) ]
# https://www.bbci.de/competition/download/competition_iv/BCICIV_1calib_1000Hz_mat.zip
# https://www.bbci.de/competition/download/competition_iv/BCICIV_1eval_1000Hz_mat.zip
# https://www.bbci.de/competition/download/competition_iv/BCICIV_1calib_1000Hz_asc.zip
# https://www.bbci.de/competition/download/competition_iv/BCICIV_1eval_1000Hz_asc.zip
#
# ## Data Sets 2
# - from Graz (description 2a; description 2b)
# - Data sets 2a: [ GDF files zipped (420 MB) ]
# https://www.bbci.de/competition/download/competition_iv/BCICIV_2a_gdf.zip
# - Data sets 2b: [ GDF files zipped (216 MB) ]
# https://www.bbci.de/competition/download/competition_iv/BCICIV_2b_gdf.zip
#
# - Remark: GDF is a general dataformat for biosignals used in the BIOSIG toolbox for Matlab and Octave.
# ## Data Sets 3
# - from Freiburg/Tübingen (description)
# - Data sets 3: [ Matlab files zipped (14 MB) ]
# https://www.bbci.de/competition/download/competition_iv/BCICIV_3_mat.zip
#
# ## Data Sets 4
# - from Washington/Albany (description)
# - Data sets 4: [ Matlab files zipped (201 MB) ]

# %% [markdown]
# ## ERPBCI
# ### https://physionet.org/content/erpbci/1.0.0/
# https://physionet.org/static/published-projects/erpbci/erp-based-brain-computer-interface-recordings-1.0.0.zip

# %% [markdown]
# # Sleep-EDF
# ## https://physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/
# https://physionet.org/files/sleep-edfx/1.0.0/sleep-cassette/
